# %% [markdown]
# # 3.3. Webscrape Toronto borough information from Wikipedia page

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('df_final.csv')

# %%
df.reset_index()
df_toronto = df[df['Borough'].str.contains('Toronto')]
print("Required Number:", df_toronto.shape[0])
# Out:
# Required Number: 39

# %%
df_toronto.head(5)
# Out:
#     Unnamed: 0 PostalCode           Borough               Neighborhood  \
# 2            2        M5A  Downtown Toronto  Regent Park, Harbourfront
# 9            9        M5B  Downtown Toronto   Garden District, Ryerson
# 15          15        M5C  Downtown Toronto             St. James Town
# 19          19        M4E      East Toronto                The Beaches
# 20          20        M5E  Downtown Toronto                Berczy Park
#
#      Latitude  Longitude
# 2   43.654260 -79.360636
# 9   43.657162 -79.378937
# 15  43.651494 -79.375418
# 19  43.676357 -79.293031
# 20  43.644771 -79.373306

# %%
df_toronto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 2 to 100
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    39 non-null     int64
#  1   PostalCode    39 non-null     object
#  2   Borough       39 non-null     object
#  3   Neighborhood  39 non-null     object
#  4   Latitude      39 non-null     float64
#  5   Longitude     39 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.1+ KB

# %% [markdown]
# #### Import  libraries for map

# %%
import folium

# %% [markdown]
# ### Creating map of Toronto using latitude and longitude values

# %%
lat_mean = df_toronto['Latitude'].mean()
long_mean = df_toronto['Longitude'].mean()
map_ = folium.Map(location=[lat_mean, long_mean], zoom_start=12)

for lat, lng, borough, neighborhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_)  
    
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a2984111c27949b1bd68a17bfb127e49%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a2984111c27949b1bd68a17bfb127e49%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a2984111c27949b1bd68a17bfb127e49%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a2984111c27949b1bd68a17bfb127e49%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6677258974359%2C%20-79.38855562564103%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ### Exploring venues in neighborhoods

# %%
venues = pd.read_json("https://raw.githubusercontent.com/ibm-developer-skills-network/yczvh-DataFilesForIBMProjects/master/segmenting_neighborhoods.json")    
venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                 'Venue', 
                 'Venue Latitude', 
                 'Venue Longitude', 
                 'Venue Category']
toronto_venues = venues
toronto_venues.head(5)
# Out:
#                              Neighborhood  Neighborhood Latitude  \
# 0                          Malvern, Rouge              43.806686
# 1  Rouge Hill, Port Union, Highland Creek              43.784535
# 2       Guildwood, Morningside, West Hill              43.763573
# 3       Guildwood, Morningside, West Hill              43.763573
# 4       Guildwood, Morningside, West Hill              43.763573
#
#    Neighborhood Longitude                  Venue  Venue Latitude  \
# 0              -79.194353                Wendy’s       43.807448
# 1              -79.160497  Royal Canadian Legion       43.782533
# 2              -79.188711         RBC Royal Bank       43.766790
# 3              -79.188711      G & G Electronics       43.765309
# 4              -79.188711             Sail Sushi       43.765951
#
#    Venue Longitude        Venue Category
# 0       -79.199056  Fast Food Restaurant
# 1       -79.163085                   Bar
# 2       -79.191151                  Bank
# 3       -79.191537     Electronics Store
# 4       -79.191275            Restaurant

# %%
toronto_venues.describe()
# Out:
#        Neighborhood Latitude  Neighborhood Longitude  Venue Latitude  \
# count            1337.000000             1337.000000     1337.000000
# mean               43.683913              -79.394406       43.683911
# std                 0.045772                0.067328        0.045597
# min                43.602414              -79.615819       43.599152
# 25%                43.650571              -79.419750       43.649552
# 50%                43.665860              -79.383160       43.665303
# 75%                43.709060              -79.363452       43.710148
# max                43.815252              -79.160497       43.815477
#
#        Venue Longitude
# count      1337.000000
# mean        -79.394235
# std           0.067369
# min         -79.621765
# 25%         -79.419702
# 50%         -79.383893
# 75%         -79.361584
# max         -79.163085

# %%
# the number of venues in each neighborhood
print(toronto_venues.groupby('Neighborhood').count().iloc[:,0])
# Out:
# Neighborhood
# Agincourt                                           4
# Alderwood, Long Branch                              8
# Bathurst Manor, Wilson Heights, Downsview North    23
# Bayview Village                                     4
# Bedford Park, Lawrence Manor East                  22
#                                                    ..
# Willowdale West                                     5
# Willowdale, Newtonbrook                             1
# Woburn                                              4
# Woodbine Heights                                    8
# York Mills West                                     2
# Name: Neighborhood Latitude, Length: 100, dtype: int64

# %%
toronto_venues.groupby('Neighborhood').count().head(50)
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Agincourt                                                               4
# Alderwood, Long Branch                                                  8
# Bathurst Manor, Wilson Heights, Downsview North                        23
# Bayview Village                                                         4
# Bedford Park, Lawrence Manor East                                      22
# Berczy Park                                                            30
# Birch Cliff, Cliffside West                                             5
# Brockton, Parkdale Village, Exhibition Place                           24
# CN Tower, King and Spadina, Railway Lands, Harb...                     17
# Caledonia-Fairbanks                                                     4
# Cedarbrae                                                               9
# Central Bay Street                                                     30
# Christie                                                               15
# Church and Wellesley                                                   30
# Clairville, Humberwood, Woodbine Downs, West Hu...                      4
# Clarks Corners, Tam O'Shanter, Sullivan                                12
# Cliffside, Cliffcrest, Scarborough Village West                         2
# Commerce Court, Victoria Hotel                                         30
# Davisville                                                             30
# Davisville North                                                        8
# Del Ray, Mount Dennis, Keelsdale and Silverthorn                        5
# Don Mills North                                                         5
# Don Mills South                                                        19
# Dorset Park, Wexford Heights, Scarborough Town ...                      7
# Downsview Central                                                       2
# Downsview East                                                          3
# Downsview Northwest                                                     4
# Downsview West                                                          5
# Dufferin, Dovercourt Village                                           14
# Enclave of L4W                                                         13
# Enclave of M4L                                                         16
# Enclave of M5E                                                         30
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...                      8
# Fairview, Henry Farm, Oriole                                           30
# First Canadian Place, Underground city                                 30
# Forest Hill North & West                                                4
# Garden District, Ryerson                                               30
# Glencairn                                                               5
# Golden Mile, Clairlea, Oakridge                                         8
# Guildwood, Morningside, West Hill                                       7
# Harbourfront East, Union Station, Toronto Islands                      30
# High Park, The Junction South                                          24
# Hillcrest Village                                                       5
# Humber Summit                                                           4
# Humberlea, Emery                                                        1
# Humewood-Cedarvale                                                      4
# India Bazaar, The Beaches West                                         22
# Kennedy Park, Ionview, East Birchmount Park                             5
# Kensington Market, Chinatown, Grange Park                              30
# Kingsview Village, St. Phillips, Martin Grove G...                      4
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Agincourt                                                                4
# Alderwood, Long Branch                                                   8
# Bathurst Manor, Wilson Heights, Downsview North                         23
# Bayview Village                                                          4
# Bedford Park, Lawrence Manor East                                       22
# Berczy Park                                                             30
# Birch Cliff, Cliffside West                                              5
# Brockton, Parkdale Village, Exhibition Place                            24
# CN Tower, King and Spadina, Railway Lands, Harb...                      17
# Caledonia-Fairbanks                                                      4
# Cedarbrae                                                                9
# Central Bay Street                                                      30
# Christie                                                                15
# Church and Wellesley                                                    30
# Clairville, Humberwood, Woodbine Downs, West Hu...                       4
# Clarks Corners, Tam O'Shanter, Sullivan                                 12
# Cliffside, Cliffcrest, Scarborough Village West                          2
# Commerce Court, Victoria Hotel                                          30
# Davisville                                                              30
# Davisville North                                                         8
# Del Ray, Mount Dennis, Keelsdale and Silverthorn                         5
# Don Mills North                                                          5
# Don Mills South                                                         19
# Dorset Park, Wexford Heights, Scarborough Town ...                       7
# Downsview Central                                                        2
# Downsview East                                                           3
# Downsview Northwest                                                      4
# Downsview West                                                           5
# Dufferin, Dovercourt Village                                            14
# Enclave of L4W                                                          13
# Enclave of M4L                                                          16
# Enclave of M5E                                                          30
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...                       8
# Fairview, Henry Farm, Oriole                                            30
# First Canadian Place, Underground city                                  30
# Forest Hill North & West                                                 4
# Garden District, Ryerson                                                30
# Glencairn                                                                5
# Golden Mile, Clairlea, Oakridge                                          8
# Guildwood, Morningside, West Hill                                        7
# Harbourfront East, Union Station, Toronto Islands                       30
# High Park, The Junction South                                           24
# Hillcrest Village                                                        5
# Humber Summit                                                            4
# Humberlea, Emery                                                         1
# Humewood-Cedarvale                                                       4
# India Bazaar, The Beaches West                                          22
# Kennedy Park, Ionview, East Birchmount Park                              5
# Kensington Market, Chinatown, Grange Park                               30
# Kingsview Village, St. Phillips, Martin Grove G...                       4
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Agincourt                                               4               4
# Alderwood, Long Branch                                  8               8
# Bathurst Manor, Wilson Heights, Downsview North        23              23
# Bayview Village                                         4               4
# Bedford Park, Lawrence Manor East                      22              22
# Berczy Park                                            30              30
# Birch Cliff, Cliffside West                             5               5
# Brockton, Parkdale Village, Exhibition Place           24              24
# CN Tower, King and Spadina, Railway Lands, Harb...     17              17
# Caledonia-Fairbanks                                     4               4
# Cedarbrae                                               9               9
# Central Bay Street                                     30              30
# Christie                                               15              15
# Church and Wellesley                                   30              30
# Clairville, Humberwood, Woodbine Downs, West Hu...      4               4
# Clarks Corners, Tam O'Shanter, Sullivan                12              12
# Cliffside, Cliffcrest, Scarborough Village West         2               2
# Commerce Court, Victoria Hotel                         30              30
# Davisville                                             30              30
# Davisville North                                        8               8
# Del Ray, Mount Dennis, Keelsdale and Silverthorn        5               5
# Don Mills North                                         5               5
# Don Mills South                                        19              19
# Dorset Park, Wexford Heights, Scarborough Town ...      7               7
# Downsview Central                                       2               2
# Downsview East                                          3               3
# Downsview Northwest                                     4               4
# Downsview West                                          5               5
# Dufferin, Dovercourt Village                           14              14
# Enclave of L4W                                         13              13
# Enclave of M4L                                         16              16
# Enclave of M5E                                         30              30
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...      8               8
# Fairview, Henry Farm, Oriole                           30              30
# First Canadian Place, Underground city                 30              30
# Forest Hill North & West                                4               4
# Garden District, Ryerson                               30              30
# Glencairn                                               5               5
# Golden Mile, Clairlea, Oakridge                         8               8
# Guildwood, Morningside, West Hill                       7               7
# Harbourfront East, Union Station, Toronto Islands      30              30
# High Park, The Junction South                          24              24
# Hillcrest Village                                       5               5
# Humber Summit                                           4               4
# Humberlea, Emery                                        1               1
# Humewood-Cedarvale                                      4               4
# India Bazaar, The Beaches West                         22              22
# Kennedy Park, Ionview, East Birchmount Park             5               5
# Kensington Market, Chinatown, Grange Park              30              30
# Kingsview Village, St. Phillips, Martin Grove G...      4               4
#
#                                                     Venue Longitude  \
# Neighborhood
# Agincourt                                                         4
# Alderwood, Long Branch                                            8
# Bathurst Manor, Wilson Heights, Downsview North                  23
# Bayview Village                                                   4
# Bedford Park, Lawrence Manor East                                22
# Berczy Park                                                      30
# Birch Cliff, Cliffside West                                       5
# Brockton, Parkdale Village, Exhibition Place                     24
# CN Tower, King and Spadina, Railway Lands, Harb...               17
# Caledonia-Fairbanks                                               4
# Cedarbrae                                                         9
# Central Bay Street                                               30
# Christie                                                         15
# Church and Wellesley                                             30
# Clairville, Humberwood, Woodbine Downs, West Hu...                4
# Clarks Corners, Tam O'Shanter, Sullivan                          12
# Cliffside, Cliffcrest, Scarborough Village West                   2
# Commerce Court, Victoria Hotel                                   30
# Davisville                                                       30
# Davisville North                                                  8
# Del Ray, Mount Dennis, Keelsdale and Silverthorn                  5
# Don Mills North                                                   5
# Don Mills South                                                  19
# Dorset Park, Wexford Heights, Scarborough Town ...                7
# Downsview Central                                                 2
# Downsview East                                                    3
# Downsview Northwest                                               4
# Downsview West                                                    5
# Dufferin, Dovercourt Village                                     14
# Enclave of L4W                                                   13
# Enclave of M4L                                                   16
# Enclave of M5E                                                   30
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...                8
# Fairview, Henry Farm, Oriole                                     30
# First Canadian Place, Underground city                           30
# Forest Hill North & West                                          4
# Garden District, Ryerson                                         30
# Glencairn                                                         5
# Golden Mile, Clairlea, Oakridge                                   8
# Guildwood, Morningside, West Hill                                 7
# Harbourfront East, Union Station, Toronto Islands                30
# High Park, The Junction South                                    24
# Hillcrest Village                                                 5
# Humber Summit                                                     4
# Humberlea, Emery                                                  1
# Humewood-Cedarvale                                                4
# India Bazaar, The Beaches West                                   22
# Kennedy Park, Ionview, East Birchmount Park                       5
# Kensington Market, Chinatown, Grange Park                        30
# Kingsview Village, St. Phillips, Martin Grove G...                4
#
#                                                     Venue Category
# Neighborhood
# Agincourt                                                        4
# Alderwood, Long Branch                                           8
# Bathurst Manor, Wilson Heights, Downsview North                 23
# Bayview Village                                                  4
# Bedford Park, Lawrence Manor East                               22
# Berczy Park                                                     30
# Birch Cliff, Cliffside West                                      5
# Brockton, Parkdale Village, Exhibition Place                    24
# CN Tower, King and Spadina, Railway Lands, Harb...              17
# Caledonia-Fairbanks                                              4
# Cedarbrae                                                        9
# Central Bay Street                                              30
# Christie                                                        15
# Church and Wellesley                                            30
# Clairville, Humberwood, Woodbine Downs, West Hu...               4
# Clarks Corners, Tam O'Shanter, Sullivan                         12
# Cliffside, Cliffcrest, Scarborough Village West                  2
# Commerce Court, Victoria Hotel                                  30
# Davisville                                                      30
# Davisville North                                                 8
# Del Ray, Mount Dennis, Keelsdale and Silverthorn                 5
# Don Mills North                                                  5
# Don Mills South                                                 19
# Dorset Park, Wexford Heights, Scarborough Town ...               7
# Downsview Central                                                2
# Downsview East                                                   3
# Downsview Northwest                                              4
# Downsview West                                                   5
# Dufferin, Dovercourt Village                                    14
# Enclave of L4W                                                  13
# Enclave of M4L                                                  16
# Enclave of M5E                                                  30
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...               8
# Fairview, Henry Farm, Oriole                                    30
# First Canadian Place, Underground city                          30
# Forest Hill North & West                                         4
# Garden District, Ryerson                                        30
# Glencairn                                                        5
# Golden Mile, Clairlea, Oakridge                                  8
# Guildwood, Morningside, West Hill                                7
# Harbourfront East, Union Station, Toronto Islands               30
# High Park, The Junction South                                   24
# Hillcrest Village                                                5
# Humber Summit                                                    4
# Humberlea, Emery                                                 1
# Humewood-Cedarvale                                               4
# India Bazaar, The Beaches West                                  22
# Kennedy Park, Ionview, East Birchmount Park                      5
# Kensington Market, Chinatown, Grange Park                       30
# Kingsview Village, St. Phillips, Martin Grove G...               4

# %%
print(f"The number of unique categories: {len(toronto_venues['Venue Category'].unique())}")
# Out:
# The number of unique categories: 241

# %% [markdown]
# ### Top 10 most common venues

# %%
# Function to sort the venues in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# %%
# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_venues_grouped['Neighborhood']

for ind in np.arange(toronto_venues_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_venues_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood      1st Most Common Venue  \
# 0                                        Agincourt  Latin American Restaurant
# 1                           Alderwood, Long Branch                Pizza Place
# 2  Bathurst Manor, Wilson Heights, Downsview North                Coffee Shop
# 3                                  Bayview Village                       Bank
# 4                Bedford Park, Lawrence Manor East                Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                Lounge          Skating Rink        Breakfast Spot
# 1          Skating Rink              Pharmacy                   Pub
# 2                  Bank                 Diner           Bridal Shop
# 3    Chinese Restaurant   Japanese Restaurant                  Café
# 4        Sandwich Place    Italian Restaurant      Greek Restaurant
#
#   5th Most Common Venue 6th Most Common Venue        7th Most Common Venue  \
# 0         Women's Store         Deli / Bodega                    Drugstore
# 1        Sandwich Place           Coffee Shop                          Gym
# 2           Supermarket            Restaurant             Sushi Restaurant
# 3         Women's Store         Deli / Bodega  Eastern European Restaurant
# 4       Thai Restaurant          Liquor Store                    Juice Bar
#
#   8th Most Common Venue      9th Most Common Venue 10th Most Common Venue
# 0            Donut Shop                    Dog Run    Distribution Center
# 1           Gas Station            Coworking Space                  Diner
# 2        Ice Cream Shop  Middle Eastern Restaurant      Mobile Phone Shop
# 3             Drugstore                 Donut Shop                Dog Run
# 4     Indian Restaurant                 Restaurant       Sushi Restaurant

# %% [markdown]
# ## Clustering K-Means

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans
kclusters = 5
toronto_venues_grouped_clustering = toronto_venues_grouped.drop('Neighborhood', 1)

# %%
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_venues_grouped_clustering)

# %%
kmeans
# Out:
# KMeans(n_clusters=5, random_state=0)

# %% [markdown]
# ### Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
toronto_merged = df_toronto

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
toronto_merged.head()
# Out:
#     Unnamed: 0 PostalCode           Borough               Neighborhood  \
# 2            2        M5A  Downtown Toronto  Regent Park, Harbourfront
# 9            9        M5B  Downtown Toronto   Garden District, Ryerson
# 15          15        M5C  Downtown Toronto             St. James Town
# 19          19        M4E      East Toronto                The Beaches
# 20          20        M5E  Downtown Toronto                Berczy Park
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 2   43.654260 -79.360636               1           Coffee Shop
# 9   43.657162 -79.378937               1                  Café
# 15  43.651494 -79.375418               1             Gastropub
# 19  43.676357 -79.293031               1                   Pub
# 20  43.644771 -79.373306               1          Cocktail Bar
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 2                   Park                Bakery        Breakfast Spot
# 9                Theater        Clothing Store   Sporting Goods Shop
# 15                  Café        Farmers Market           Coffee Shop
# 19                 Trail     Health Food Store          Dance Studio
# 20           Coffee Shop              Beer Bar        Farmers Market
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 2                   Café      Greek Restaurant  Gym / Fitness Center
# 9                  Hotel  Fast Food Restaurant            Steakhouse
# 15       Thai Restaurant                 Diner             Jazz Club
# 19         Deli / Bodega      Department Store          Dessert Shop
# 20    Seafood Restaurant                  Café        Breakfast Spot
#
#    8th Most Common Venue  9th Most Common Venue   10th Most Common Venue
# 2                    Pub  Performing Arts Venue       Mexican Restaurant
# 9                 Bakery       Ramen Restaurant              Music Venue
# 15   Japanese Restaurant     Italian Restaurant               Restaurant
# 19    Dim Sum Restaurant          Women's Store             Cupcake Shop
# 20          Liquor Store                 Bistro  Comfort Food Restaurant

# %% [markdown]
# ### Visualize the clusters

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_ = folium.Map(location=[lat_mean, long_mean], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_)
       
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fdf09354f0d24608b321b78f7c96a6aa%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fdf09354f0d24608b321b78f7c96a6aa%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fdf09354f0d24608b321b78f7c96a6aa%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fdf09354f0d24608b321b78f7c96a6aa%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6677258974359%2C%20-79.38855562564103%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# #### Above shows visualization of cluster and below is some summary statistics

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#     PostalCode  Longitude  Cluster Labels    1st Most Common Venue  \
# 2          M5A -79.360636               1              Coffee Shop
# 9          M5B -79.378937               1                     Café
# 15         M5C -79.375418               1                Gastropub
# 19         M4E -79.293031               1                      Pub
# 20         M5E -79.373306               1             Cocktail Bar
# 24         M5G -79.387383               1              Coffee Shop
# 25         M6G -79.422564               1            Grocery Store
# 30         M5H -79.384568               1              Coffee Shop
# 31         M6H -79.442259               1                 Pharmacy
# 35         M4J -79.338106               1              Pizza Place
# 36         M5J -79.381752               1                     Park
# 37         M6J -79.419750               1                      Bar
# 41         M4K -79.352188               1         Greek Restaurant
# 42         M5K -79.381576               1                     Café
# 43         M6K -79.428191               1                     Café
# 47         M4L -79.315572               1                     Park
# 48         M5L -79.379817               1                     Café
# 54         M4M -79.340923               1              Coffee Shop
# 62         M5N -79.416936               1  Health & Beauty Service
# 67         M4P -79.390197               1              Pizza Place
# 69         M6P -79.464763               1                     Café
# 73         M4R -79.405678               1           Clothing Store
# 74         M5R -79.405678               1                     Café
# 75         M6R -79.456325               1                Gift Shop
# 79         M4S -79.388790               1             Dessert Shop
# 80         M5S -79.400049               1                     Café
# 81         M6S -79.484450               1                     Café
# 84         M5T -79.400049               1                     Café
# 86         M4V -79.400049               1              Coffee Shop
# 87         M5V -79.394420               1          Airport Service
# 92         M5W -79.374846               1       Seafood Restaurant
# 96         M4X -79.367675               1              Coffee Shop
# 97         M5X -79.382280               1                     Café
# 99         M4Y -79.383160               1              Coffee Shop
# 100        M7Y -79.321558               1              Pizza Place
#
#      2nd Most Common Venue  3rd Most Common Venue   4th Most Common Venue  \
# 2                     Park                 Bakery          Breakfast Spot
# 9                  Theater         Clothing Store     Sporting Goods Shop
# 15                    Café         Farmers Market             Coffee Shop
# 19                   Trail      Health Food Store            Dance Studio
# 20             Coffee Shop               Beer Bar          Farmers Market
# 24      Italian Restaurant                   Café             Yoga Studio
# 25                    Café                   Park              Baby Store
# 30                    Café     Seafood Restaurant         Thai Restaurant
# 31                  Bakery                   Park                    Pool
# 35                    Park      Convenience Store            Intersection
# 36                   Plaza                   Café                   Hotel
# 37        Asian Restaurant  Vietnamese Restaurant             Men's Store
# 41      Italian Restaurant         Ice Cream Shop                     Spa
# 42             Coffee Shop             Restaurant                  Bakery
# 43             Coffee Shop         Breakfast Spot                  Bakery
# 47             Pizza Place   Fast Food Restaurant               Pet Store
# 48                   Hotel             Restaurant             Coffee Shop
# 54                    Café    American Restaurant                  Bakery
# 62                  Garden          Women's Store             Curling Ice
# 67          Breakfast Spot                  Hotel          Sandwich Place
# 69      Mexican Restaurant        Thai Restaurant                    Park
# 73             Coffee Shop    Sporting Goods Shop  Furniture / Home Store
# 74          Sandwich Place            Coffee Shop                Pharmacy
# 75          Breakfast Spot       Cuban Restaurant            Dessert Shop
# 79             Coffee Shop                    Gym          Sandwich Place
# 80                  Bakery                    Bar      Italian Restaurant
# 81             Pizza Place       Sushi Restaurant             Coffee Shop
# 84   Vietnamese Restaurant     Mexican Restaurant      Belgian Restaurant
# 86                    Café       Sushi Restaurant             Supermarket
# 87          Airport Lounge       Airport Terminal             Coffee Shop
# 92                Beer Bar         Farmers Market                    Café
# 96              Restaurant     Italian Restaurant                    Café
# 97             Coffee Shop             Restaurant      Seafood Restaurant
# 99        Sushi Restaurant               Beer Bar                     Pub
# 100          Auto Workshop             Skate Park      Light Rail Station
#
#            5th Most Common Venue        6th Most Common Venue  \
# 2                           Café             Greek Restaurant
# 9                          Hotel         Fast Food Restaurant
# 15               Thai Restaurant                        Diner
# 19                 Deli / Bodega             Department Store
# 20            Seafood Restaurant                         Café
# 24               Thai Restaurant             Department Store
# 25                   Candy Store                  Coffee Shop
# 30                    Smoke Shop                       Lounge
# 31                       Brewery                          Bar
# 35                  Dance Studio  Eastern European Restaurant
# 36         Performing Arts Venue                 Skating Rink
# 37              Greek Restaurant               Ice Cream Shop
# 41                           Pub                  Pizza Place
# 42           Japanese Restaurant               Sandwich Place
# 43                   Yoga Studio                 Intersection
# 47                           Pub                   Board Shop
# 48                     Gastropub          American Restaurant
# 54                   Yoga Studio                    Pet Store
# 62   Eastern European Restaurant                    Drugstore
# 67              Department Store            Food & Drink Shop
# 69            Italian Restaurant                       Bakery
# 73                Ice Cream Shop         Fast Food Restaurant
# 74              Asian Restaurant                  Pizza Place
# 75                     Bookstore                  Coffee Shop
# 79            Italian Restaurant                         Café
# 80           Japanese Restaurant                    Bookstore
# 81            Italian Restaurant                          Pub
# 84                   Record Shop                       Bakery
# 86                    Bagel Shop                          Pub
# 87                 Boat or Ferry                          Bar
# 92                  Cocktail Bar                  Art Gallery
# 96                        Bakery                         Park
# 97                         Hotel                    Gastropub
# 99              Ramen Restaurant                   Steakhouse
# 100                         Park                      Brewery
#
#          7th Most Common Venue        8th Most Common Venue  \
# 2         Gym / Fitness Center                          Pub
# 9                   Steakhouse                       Bakery
# 15                   Jazz Club          Japanese Restaurant
# 19                Dessert Shop           Dim Sum Restaurant
# 20              Breakfast Spot                 Liquor Store
# 24              Sandwich Place                          Spa
# 25          Italian Restaurant                    Nightclub
# 30                      Bakery                   Steakhouse
# 31                        Bank                  Supermarket
# 35                   Drugstore                   Donut Shop
# 36                 IT Services               Ice Cream Shop
# 37                 Pizza Place      New American Restaurant
# 41                   Juice Bar                Grocery Store
# 42                    Beer Bar                  Art Gallery
# 43       Performing Arts Venue                    Pet Store
# 47                     Brewery               Sandwich Place
# 48                 Tailor Shop               Sandwich Place
# 54            Stationery Store                    Bookstore
# 62                  Donut Shop                      Dog Run
# 67        Gym / Fitness Center                         Park
# 69   Cajun / Creole Restaurant                  Flea Market
# 73                       Diner           Mexican Restaurant
# 74                         Pub    Middle Eastern Restaurant
# 75                     Dog Run  Eastern European Restaurant
# 79            Sushi Restaurant                  Pizza Place
# 80              Sandwich Place                         Bank
# 81           Fish & Chips Shop                 Dessert Shop
# 84                         Bar               Farmers Market
# 86                        Bank          Fried Chicken Joint
# 87                     Airport           Airport Food Court
# 92                  Restaurant                    Jazz Club
# 96                  Beer Store                      Butcher
# 97                         Gym                   Steakhouse
# 99        Ethiopian Restaurant                  Escape Room
# 100              Burrito Place               Farmers Market
#
#        9th Most Common Venue     10th Most Common Venue
# 2      Performing Arts Venue         Mexican Restaurant
# 9           Ramen Restaurant                Music Venue
# 15        Italian Restaurant                 Restaurant
# 19             Women's Store               Cupcake Shop
# 20                    Bistro    Comfort Food Restaurant
# 24       Japanese Restaurant            Bubble Tea Shop
# 25                Restaurant              Deli / Bodega
# 30                     Hotel       Fast Food Restaurant
# 31                      Café  Middle Eastern Restaurant
# 35                   Dog Run        Distribution Center
# 36       Sporting Goods Shop         Basketball Stadium
# 37         Korean Restaurant        Japanese Restaurant
# 41    Furniture / Home Store    Fruit & Vegetable Store
# 42                     Hotel                 Steakhouse
# 43         Convenience Store               Climbing Gym
# 47        Italian Restaurant                 Steakhouse
# 48   New American Restaurant        Japanese Restaurant
# 54                   Brewery         Seafood Restaurant
# 62       Distribution Center             Discount Store
# 67            Discount Store                Curling Ice
# 69      Fast Food Restaurant                  Speakeasy
# 73                      Park         Chinese Restaurant
# 74              Burger Joint               Liquor Store
# 75        Italian Restaurant                        Bar
# 79                  Pharmacy                    Brewery
# 80                  Beer Bar                Yoga Studio
# 81                      Bank                        Bar
# 84                  Beer Bar                  Jazz Club
# 86       American Restaurant                Pizza Place
# 87              Airport Gate        Rental Car Location
# 92                    Bakery                   Creperie
# 96                       Pub       Caribbean Restaurant
# 97                       Pub                  Speakeasy
# 99         Indian Restaurant         Italian Restaurant
# 100     Fast Food Restaurant                 Restaurant
